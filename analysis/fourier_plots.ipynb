# %%
import Pkg
Pkg.activate("./")
Pkg.instantiate()
#Pkg.precompile()
# Out:
#   Activating project at `~/Desktop/git_projects/Causal sets/CausalSetZoology/analysis`
# Precompiling packages...
#    5087.3 ms  ✓ CausalSetZoology
#   1 dependency successfully precompiled in 20 seconds. 418 already precompiled.

# %%
function fig_path(fig_name::String)
        path = "/Users/fabianwagner/Dropbox/Fabian/Research/Shared Folders/CausalSetZoology/figs/"
        #"/Users/fabian/Dropbox/Fabian/Research/Shared Folders/CausalSetZoology/figs/"
        return "$(path)$(fig_name)"
end

using Revise
includet("analysis.jl")

# %%
import Colors
colors = [
                Colors.colorant"#F1C21B",  # IBM Yellow
                Colors.colorant"#D12771",  # IBM Magenta
                Colors.colorant"#009D9A",  # IBM Teal
                Colors.colorant"#0F62FE",  # IBM Blue
                Colors.colorant"#6F6F6F",  # IBM Gray
                Colors.colorant"#FA4D56",  # IBM Red
                Colors.colorant"#24A148",  # IBM Green
        ]
# Out:
# 7-element Vector{RGB{FixedPointNumbers.N0f8}}:
#  RGB(0.945, 0.761, 0.106)
#  RGB(0.82, 0.153, 0.443)
#  RGB(0.0, 0.616, 0.604)
#  RGB(0.059, 0.384, 0.996)
#  RGB(0.435, 0.435, 0.435)
#  RGB(0.98, 0.302, 0.337)
#  RGB(0.141, 0.631, 0.282)

# %%
candidates = [
    "/Volumes/Causal Set Silo/causal_sets/analysis/",
    "/Volumes/Causal Set Silochen/causal_sets/analysis/",
]

root_path = let p = findfirst(isdir, candidates)
    p === nothing && error("No analysis path found")
    candidates[p]
end

data_path_man = [joinpath(root_path,"manifoldlike_simply_connected_2048_10000/statistics.jld2")]

function data_paths(file_names::Vector{String})::Vector{String}
    return [joinpath(root_path, file_name) for file_name in file_names]
end
# Out:
# data_paths (generic function with 1 method)

# %%
abundance_hists_comp_grid_man=load_histograms_from_paths(data_path_man, :cardinalities_hist)
average_abundance_hists_comp_grid_man, std_abundance_hists_comp_grid_man = average_histogram_with_std(abundance_hists_comp_grid_man[1])
# Out:
# ([2048.0, 12037.8474, 10051.7618, 9074.9844, 8431.9683, 7954.7587, 7575.2675, 7260.0384, 6995.4993, 6764.4528  …  0.0, 0.0001, 0.0002, 0.0001, 0.0001, 0.0002, 0.0, 0.0, 0.0001, 0.0002], [0.0, 314.8249937873775, 296.16338575312454, 285.0415905734612, 277.8503865304401, 272.37929927641, 266.4432152330991, 262.70531004424, 256.7777774642899, 252.13234892047734  …  0.0, 0.009999499987499376, 0.019998999974998752, 0.009999499987499376, 0.009999499987499376, 0.019998999974998752, 0.0, 0.0, 0.009999499987499376, 0.019998999974998752])

# %%
fourier_transform_grid_deviation(
    average_abundance_hists_comp_grid_man, 
    2048, 
    "quadratic"; 
    rotation_angle=17., 
    max_peak_order=20, 
    xtick_fracs=Any[1//2,1//4, 0.317, 0.122],
    ylim = (0., 100.)
    )
# Out:
# spec.idx = 1705
# spec.f_peak = 0.4994131455399061
# spec.P_est = 2.00235017626322
# f = 0.4994131455399061  P ≈ 2.00235017626322  A = 0.15449089751626663
# f = 0.3174882629107981  P ≈ 3.1497227356746764  A = 0.0371860138151777
# f = 0.25  P ≈ 4.0  A = 0.03513495307190906
# f = 0.12206572769953052  P ≈ 8.192307692307692  A = 0.03488602838723327
# f = 0.12147887323943662  P ≈ 8.231884057971014  A = 0.029516134259923263
# f = 0.3415492957746479  P ≈ 2.927835051546392  A = 0.02884323825522221
# f = 0.1431924882629108  P ≈ 6.9836065573770485  A = 0.028586408269857994
# f = 0.24354460093896713  P ≈ 4.106024096385543  A = 0.027860052277812155
# f = 0.1437793427230047  P ≈ 6.955102040816326  A = 0.026196154066315588
# f = 0.30809859154929575  P ≈ 3.245714285714286  A = 0.02617677697941919
# f = 0.323943661971831  P ≈ 3.0869565217391304  A = 0.02540839688648482
# f = 0.2717136150234742  P ≈ 3.6803455723542116  A = 0.02423717199315144
# f = 0.4454225352112676  P ≈ 2.2450592885375493  A = 0.02406187992777436
# f = 0.14964788732394366  P ≈ 6.682352941176471  A = 0.023413389346642652
# f = 0.15610328638497653  P ≈ 6.406015037593985  A = 0.02331451615515472
# f = 0.14906103286384975  P ≈ 6.708661417322835  A = 0.023269818171443545
# f = 0.0880281690140845  P ≈ 11.360000000000001  A = 0.023257412854486105
# f = 0.25880281690140844  P ≈ 3.863945578231293  A = 0.023231134603884814
# f = 0.34683098591549294  P ≈ 2.883248730964467  A = 0.023127528113603323
# f = 0.2963615023474178  P ≈ 3.3742574257425746  A = 0.02227710560904918

# %%
fourier_transform_grid_deviation(
    average_abundance_hists_comp_grid_man, 
    2048, 
    "hexagonal"; 
    rotation_angle=17., 
    max_peak_order=20, 
    xtick_fracs=Any[1//2, 1//3,1//4, 1//8, 1//6, 3//8],
    ylim = (0., 100.)
    )
# Out:
# spec.idx = 1705
# spec.f_peak = 0.4994131455399061
# spec.P_est = 2.00235017626322
# f = 0.4994131455399061  P ≈ 2.00235017626322  A = 0.1643283303900184
# f = 0.25  P ≈ 4.0  A = 0.06039406887482954
# f = 0.3333333333333333  P ≈ 3.0  A = 0.04972707876711951
# f = 0.125  P ≈ 8.0  A = 0.04632393713250134
# f = 0.16725352112676056  P ≈ 5.978947368421053  A = 0.043816315623780466
# f = 0.375  P ≈ 2.6666666666666665  A = 0.04345105452074157
# f = 0.1813380281690141  P ≈ 5.514563106796116  A = 0.034541483641642355
# f = 0.1255868544600939  P ≈ 7.962616822429906  A = 0.031376792667768945
# f = 0.2863849765258216  P ≈ 3.4918032786885242  A = 0.02974401762096987
# f = 0.16666666666666666  P ≈ 6.0  A = 0.02905796539006585
# f = 0.12441314553990611  P ≈ 8.037735849056604  A = 0.029034985264341156
# f = 0.3004694835680751  P ≈ 3.328125  A = 0.028493474583407254
# f = 0.16784037558685447  P ≈ 5.9580419580419575  A = 0.028102889864601802
# f = 0.36326291079812206  P ≈ 2.752827140549273  A = 0.02805532805223468
# f = 0.2517605633802817  P ≈ 3.972027972027972  A = 0.02755119923567579
# f = 0.2482394366197183  P ≈ 4.028368794326241  A = 0.025011404890351852
# f = 0.31279342723004694  P ≈ 3.196998123827392  A = 0.024539059080587566
# f = 0.3532863849765258  P ≈ 2.830564784053156  A = 0.024338090918662614
# f = 0.11737089201877934  P ≈ 8.52  A = 0.02277503381873985
# f = 0.4706572769953052  P ≈ 2.1246882793017456  A = 0.022119574631958013

# %%
import JLD2
crystal = JLD2.load("/Volumes/Causal Set Silo/causal_sets/crystals/spacetime_quasicrystal_5e8.jld2", "big_set")
# Out:
# ([-0.0, 3.168295237763529e-9, 4.057869939148591e-9, 6.5932735753397345e-9, 8.444508093231058e-9, 9.761578553059508e-9, 1.3720713605361876e-8, 1.5037790830032666e-8, 1.7573180566125646e-8, 2.0314019868585074e-8  …  0.9999999739822985, 0.9999999796859866, 0.9999999824268029, 0.999999984962211, 0.9999999862792556, 0.9999999902384414, 0.9999999915554894, 0.9999999934067284, 0.9999999959421219, 0.9999999968316903], [-0.0, 0.5970385857312627, 0.7646729343177319, 0.28689723001071993, 0.36745120326051606, 0.8839358157421118, 0.1378638207897307, 0.6543484332712772, 0.1765727289642493, 0.42476105080057075  …  0.4559760677751973, 0.5752389491994702, 0.8234272710357218, 0.3456515667287334, 0.8621361792102133, 0.11606418425797718, 0.632548796739507, 0.7131027699892776, 0.23532706568222586, 0.4029614142686322])

# %%
grid_fourier_plot_matrix(
    fig_path("graph_observables/abundances/comp_grid_fourier_matrix.pdf"),
    comp_hists = [average_abundance_hists_comp_grid_man for i in 1:4],
    sizes = [2048 for i in 1:4],
    lattices = ["quadratic", "hexagonal", "hexagonal", "quasicrystal"],
    rotation_angles = [1e-13, 0., 17., 0.],
    fourier_yaxis_side = :right,
    ylims_fourier = [(0., 100.) for i in 1:4],
    xtick_fracss = [[1//12, 1//4,1//2,1//3, 2//7, 2//5,1//5, 1//6, 1//8], Any[1//2, .211, .144, .355, .29], Any[1//2, 1//3,1//4, 1//8, 1//6, 3//8], []],
    quasicrystal_crystal = crystal,
    remove_coordinate_ticks = true,
    )
